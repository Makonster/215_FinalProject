# %%
import pandas as pd
import numpy as np
from scipy import stats 
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pycmap
import cmocean

# %%
#Got help from Kathy for accesing the ARGO data
#And for setting up the query
#Due to large data acess only january was used
key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2013-01-01' and '2013-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data13=api.query(query)  
data13['temperature'].mean()
#Filter data
filtered_df13 = data13.query('505 >depth > 500')
fil13mean = filtered_df13.mean()

#Plot the data
#Tried to plot on one figure, but was given errors. Tried several work arounds to no avail. 
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(filtered_df13['depth'], filtered_df13['temperature'], marker= "*", label= 'Temperature', markersize= 10,
        color= 'forestgreen', linestyle = 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2013', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2013_ArgoFloat')
#used the prelectures and in class demos for set up
#Used Matplotlib website for color options and marker shape options

# %%
key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2014-01-01' and '2014-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data14=api.query(query)  
data14['temperature'].mean()
filtered_df14 = data14.query('505 >depth > 500')
fil14mean = filtered_df14.mean()


fig, ax = plt.subplots(figsize=(15,8))
ax.plot(filtered_df14['temperature'], filtered_df14['depth'], marker= "*", label= 'Temperature', markersize= 10,
        color= 'darkgreen', linestyle = 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2014', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2014_ArgoFloat')

# %%
y= filtered_df14['depth']
x= filtered_df14['temperature']
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(x, y, marker= "*", label= 'Temperature', markersize= 10,
        color= 'darkgreen', linestyle = 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2014', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2014_ArgoFloat')

# %%
key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2015-01-01' and '2015-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data15=api.query(query) 
data15['temperature'].mean()
filtered_df15 = data15.query('505 >depth > 500')
fil15mean = filtered_df15.mean()


fig, ax = plt.subplots(figsize=(15,8))
ax.plot(filtered_df15['temperature'], filtered_df15['depth'], marker= "*", label= 'Temperature', markersize= 10,
        color= 'seagreen', linestyle = 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2015', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2015_ArgoFloat')

# %%
y= filtered_df15['depth']
x= filtered_df15['temperature']
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(x, y, marker= "*", label= 'Temperature', markersize= 10,
        color= 'seagreen', linestyle = 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2015', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2015_ArgoFloat')

# %%
key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2016-01-01' and '2016-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data16=api.query(query)  
data16['temperature'].mean()
filtered_df16 = data16.query('505 >depth > 500')
fil16mean = filtered_df16.mean()


fig, ax = plt.subplots(figsize=(15,8))
ax.plot(filtered_df16['temperature'], filtered_df16['depth'], marker= "*", label= 'Temperature', markersize= 10,
        color= 'mediumaquamarine', linestyle = 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2016', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2016_ArgoFloat')

# %%
y= filtered_df16['depth']
x= filtered_df16['temperature']
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(x, y, marker= "*", label= 'Temperature', markersize= 10,
        color= 'mediumaquamarine', linestyle = 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2016', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2016_ArgoFloat')

# %%
# key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2017-01-01' and '2017-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data17=api.query(query) 
data17['temperature'].mean()
filtered_df17 = data17.query('505 >depth > 500')
fil17mean = filtered_df17.mean()


fig, ax = plt.subplots(figsize=(15,8))
ax.plot(filtered_df17['temperature'], filtered_df17['depth'], marker= "*", label= 'Temperature', linestyle = 'None', markersize= 10,
        color= 'lightseagreen')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2017', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2017_ArgoFloat')

# %%
key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2018-01-01' and '2018-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data18=api.query(query)  
data18['temperature'].mean()
filtered_df18 = data18.query('505 >depth > 500')
fil18mean = filtered_df18.mean()


fig, ax = plt.subplots(figsize=(15,8))
ax.plot(filtered_df18['temperature'], filtered_df18['depth'], marker= "*", label= 'Temperature', markersize= 10,
        color= 'mediumturquoise', linestyle = 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2018', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2018_ArgoFloat')

# %%
key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2019-01-01' and '2019-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data19=api.query(query) 
data19['temperature'].mean()
filtered_df19 = data19.query('505 >depth > 500')
fil19mean = filtered_df19.mean()


fig, ax = plt.subplots(figsize=(15,8))
ax.plot( filtered_df19['temperature'], filtered_df19['depth'], marker= "*", label= 'Temperature', color= 'teal',
       linestyle= 'None', markersize= 10)
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2019 ', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2019_ArgoFloat')

# %%
key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2020-01-01' and '2020-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data20=api.query(query)  
data20['temperature'].mean()
filtered_df20 = data20.query('505 >depth > 500')
fil20mean = filtered_df20.mean()


fig, ax = plt.subplots(figsize=(15,8))
ax.plot(filtered_df20['temperature'], filtered_df20['depth'], marker= "*", label= 'Temperature', color= 'darkturquoise',
       markersize= 10, linestyle= 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2020', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2020_ArgoFloat')

# %%
key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2021-01-01' and '2021-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data21=api.query(query)  
data21['temperature'].mean()
filtered_df21 = data21.query('505 >depth > 500')
fil21mean = filtered_df21.mean()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(filtered_df21['temperature'], filtered_df21['depth'], marker= "*", label= 'Temperature', 
        color= 'cadetblue', linestyle= 'None', markersize= 10)
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2021', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2021_ArgoFloat')

# %%
key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2022-01-01' and '2022-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data22=api.query(query)  
data22['temperature'].mean()
filtered_df22 = data22.query('505 >depth > 500')
fil22mean = filtered_df22.mean()


fig, ax = plt.subplots(figsize=(15,8))
ax.plot(filtered_df22['temperature'], filtered_df22['depth'], marker= "*", label= 'Temperature', markersize= 10,
        color= 'steelblue', linestyle = 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2022', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2022_ArgoFloat')

# %%
key = "d7672c4a-8277-4127-a1bf-45889999d607"
api = pycmap.API(token=key)

# access data by querying on a monthly basis 
query = ''' 
select datepart('year', time) year, datepart('month', time) month,
floor(lat/3)*3 lat, floor(lon/3)*3 lon, avg(depth) depth, avg(temp) temperature
from tblArgoCore_REP_Nov2023
where time between '2023-01-01' and '2023-01-31' 
and depth between 0 and 1000
group by 1, 2, 3, 4
order by 1, 2, 3, 4 
'''
# make query
data=api.query(query) 
#sea_level = np.genfromtxt(data, usecols=(-1,-2,-3,-4), dtype= float, delimiter= '')
data['temperature'].mean()
filtered_df23 = data.query('505 >depth > 500')
fil23mean = filtered_df23.mean()

fig, ax = plt.subplots(figsize=(15,8))
ax.plot(filtered_df23['temperature'], filtered_df23['depth'], marker= "*", label= 'Temperature', markersize= 10,
        color= 'cornflowerblue', linestyle = 'None')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.legend(loc= 'lower right')
ax.set_title('ARGO Float 2022', fontsize= '18')
ax.grid(linestyle= '-')
plt.savefig('2022_ArgoFloat')

# %%
#Used means to make a graph of the averages 

fig, ax = plt.subplots(figsize=(10,6))
ax.plot(fil23mean['temperature'], fil23mean['depth'], marker= "*", label= 'Temperature 2023', color= 'cornflowerblue',
        linestyle= 'None', markersize= 10)
ax.plot(fil22mean['temperature'], fil22mean['depth'], marker= 'D',
        color= 'steelblue', markersize= 10, 
        label= 'Temperature 2022', linestyle= 'None')
ax.plot(fil21mean['temperature'], fil21mean['depth'], marker= 'x',
        color= 'cadetblue', markersize= 10, 
        label= 'Temperature 2021', linestyle= 'None')
ax.plot(fil20mean['temperature'], fil20mean['depth'], marker= '+',
        color= 'darkturquoise', markersize= 10, 
        label= 'Temperature 2020', linestyle= 'None')
ax.plot(fil19mean['temperature'], fil19mean['depth'], marker= 'H',
        color= 'teal', markersize= 10, 
        label= 'Temperature 2019', linestyle= 'None')
ax.plot(fil18mean['temperature'], fil18mean['depth'], marker= 'p',
        color= 'mediumturquoise', markersize= 10, 
        label= 'Temperature 2018', linestyle= 'None')
ax.plot(fil17mean['temperature'], fil17mean['depth'], marker= 's',
        color= 'lightseagreen', markersize= 10, 
        label= 'Temperature 2017', linestyle= 'None')
ax.plot(fil16mean['temperature'], fil16mean['depth'], marker= '^',
        color= 'mediumaquamarine', markersize= 10, 
        label= 'Temperature 2016', linestyle= 'None')
ax.plot(fil15mean['temperature'], fil15mean['depth'], marker= '<',
        color= 'seagreen', markersize= 10, 
        label= 'Temperature 2015', linestyle= 'None')
ax.plot(fil14mean['temperature'], fil14mean['depth'], marker= '>',
        color= 'darkgreen', markersize= 10, 
        label= 'Temperature 2014', linestyle= 'None')
ax.plot(fil13mean['temperature'], fil13mean['depth'], marker= 'o',
        color= 'forestgreen', markersize= 10, 
        label= 'Temperature 2013', linestyle= 'None')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.set_xlabel('Temperature (C)', fontsize = '14')
ax.invert_yaxis()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_title('ARGO Float Year Average 2013 -2023', fontsize= '18')
ax.grid(linestyle= '-')
plt.rcParams.update({'font.size':15})
plt.savefig('2013-2023_ArgoFloat')

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(x, y, marker= "*", label= 'Temperature 2023', color= 'cornflowerblue',
        linestyle= 'None', markersize= 10)
ax.plot(filtered_df22['temperature'], filtered_df22['depth'], marker= 'D',
        color= 'steelblue', markersize= 10, 
        label= 'Temperature 2022', linestyle= 'None')
ax.plot(filtered_df21['temperature'], filtered_df21['depth'], marker= 'x',
        color= 'cadetblue', markersize= 10, 
        label= 'Temperature 2021', linestyle= 'None')
ax.plot(filtered_df20['temperature'], filtered_df20['depth'], marker= '+',
        color= 'darkturquoise', markersize= 10, 
        label= 'Temperature 2020', linestyle= 'None')
ax.plot(filtered_df19['temperature'], filtered_df19['depth'], marker= 'H',
        color= 'teal', markersize= 10, 
        label= 'Temperature 2019', linestyle= 'None')
ax.plot(filtered_df18['temperature'], filtered_df18['depth'], marker= 'p',
        color= 'mediumturquoise', markersize= 10, 
        label= 'Temperature 2018', linestyle= 'None')
ax.plot(filtered_df17['temperature'], filtered_df17['depth'], marker= 's',
        color= 'lightseagreen', markersize= 10, 
        label= 'Temperature 2017', linestyle= 'None')
ax.plot(filtered_df16['temperature'], filtered_df16['depth'], marker= '^',
        color= 'mediumaquamarine', markersize= 10, 
        label= 'Temperature 2016', linestyle= 'None')
ax.plot(filtered_df15['temperature'], filtered_df15['depth'], marker= '<',
        color= 'seagreen', markersize= 10, 
        label= 'Temperature 2015', linestyle= 'None')
ax.plot(filtered_df14['temperature'], filtered_df14['depth'], marker= '>',
        color= 'darkgreen', markersize= 10, 
        label= 'Temperature 2014', linestyle= 'None')
ax.plot(filtered_df13['temperature'], filtered_df13['depth'], marker= 'o',
        color= 'forestgreen', markersize= 10, 
        label= 'Temperature 2013', linestyle= 'None')
ax.legend(loc= 'lower right')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.set_title('ARGO Float 2023', fontsize= '18')
ax.grid(linestyle= '-')
plt.rcParams.update({'font.size':15})
plt.savefig('filall_ArgoFloat')

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax.plot(x, y, marker= "*", label= 'Temperature 2023', color= 'cornflowerblue',
        linestyle= 'None', markersize= 10)
ax.plot(data22['temperature'], data22['depth'], marker= 'D',
        color= 'steelblue', markersize= 10, 
        label= 'Temperature 2022', linestyle= 'None')
ax.plot(data21['temperature'], data21['depth'], marker= 'x',
        color= 'cadetblue', markersize= 10, 
        label= 'Temperature 2021', linestyle= 'None')
ax.plot(data20['temperature'], data20['depth'], marker= '+',
        color= 'darkturquoise', markersize= 10, 
        label= 'Temperature 2020', linestyle= 'None')
ax.plot(data19['temperature'], data19['depth'], marker= 'H',
        color= 'teal', markersize= 10, 
        label= 'Temperature 2019', linestyle= 'None')
ax.plot(data18['temperature'], data18['depth'], marker= 'p',
        color= 'mediumturquoise', markersize= 10, 
        label= 'Temperature 2018', linestyle= 'None')
ax.plot(data17['temperature'], data17['depth'], marker= 's',
        color= 'lightseagreen', markersize= 10, 
        label= 'Temperature 2017', linestyle= 'None')
ax.plot(data16['temperature'], data16['depth'], marker= '^',
        color= 'mediumaquamarine', markersize= 10, 
        label= 'Temperature 2016', linestyle= 'None')
ax.plot(data15['temperature'], data15['depth'], marker= '<',
        color= 'seagreen', markersize= 10, 
        label= 'Temperature 2015', linestyle= 'None')
ax.plot(data14['temperature'], data14['depth'], marker= '>',
        color= 'darkgreen', markersize= 10, 
        label= 'Temperature 2014', linestyle= 'None')
ax.plot(data13['temperature'], data13['depth'], marker= 'o',
        color= 'forestgreen', markersize= 10, 
        label= 'Temperature 2013', linestyle= 'None')
ax.legend(loc= 'lower right')
ax.set_xlabel('Temperature (C)', fontsize= '14')
ax.set_ylabel('Depth (M)', fontsize= '14')
ax.invert_yaxis()
ax.set_title('ARGO Float 2023', fontsize= '18')
ax.grid(linestyle= '-')
plt.rcParams.update({'font.size':15})
plt.savefig('all_ArgoFloat')
